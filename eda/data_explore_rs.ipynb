# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_raw_df = pd.read_csv('data.csv')

# %% [markdown]
# # Basic Data Descriptions

# %%
data_raw_df.head(n=10)
# Out:
#    Unnamed: 0  FIPS  visit_Grocery Stores  \
# 0           0  1001                     0
# 1           1  1003                     0
# 2           2  1005                     1
# 3           3  1007                     1
# 4           4  1009                     1
# 5           5  1011                     0
# 6           6  1013                     0
# 7           7  1015                     0
# 8           8  1017                     0
# 9           9  1019                     0
#
#    visit_Building Material and Supplies Dealers  visit_Gasoline Stations  \
# 0                                             0                        0
# 1                                             1                        0
# 2                                             0                        0
# 3                                             0                        1
# 4                                             0                        0
# ...

# %%
#Data Types
data_raw_df.dtypes
# Out:
# Unnamed: 0                                                                          int64
# FIPS                                                                                int64
# visit_Grocery Stores                                                                int64
# visit_Building Material and Supplies Dealers                                        int64
# visit_Gasoline Stations                                                             int64
# visit_General Merchandise Stores, including Warehouse Clubs and Supercenters        int64
# visit_Health and Personal Care Stores                                               int64
# fraction_pop_under_5                                                              float64
# fraction_pop_over_65                                                              float64
# dis_5to64_rate                                                                    float64
# ...

# %%
#Data Summary
data_raw_df.describe()
# Out:
#        Unnamed: 0          FIPS  visit_Grocery Stores  \
# count   528.00000    528.000000            528.000000
# mean    263.50000  32239.274621              0.426136
# std     152.56474  15985.617893              0.494983
# min       0.00000   1001.000000              0.000000
# 25%     131.75000  22114.500000              0.000000
# 50%     263.50000  34038.000000              0.000000
# 75%     395.25000  51001.500000              1.000000
# max     527.00000  51840.000000              1.000000
#
#        visit_Building Material and Supplies Dealers  visit_Gasoline Stations  \
# count                                    528.000000               528.000000
# mean                                       0.473485                 0.270833
# std                                        0.499770                 0.444812
# min                                        0.000000                 0.000000
# 25%                                        0.000000                 0.000000
# ...

# %% [markdown]
# ### Notes about the Description
#
# It seems the following fields are actually bools:
#
# visit_Grocery Stores
# visit_Building Material and Supplies Dealers
# visit_Gasoline Stations
# visit_General Merchandise Stores, including Warehouse Clubs and Supercenters
# visit_Health and Personal Care Stores
#
# Additionally have this weird unnamed column to deal with:
# Unnamed: 0
#
# Additional Questions:
# fraction_pop_under_<value> is this a percentage?

# %% [markdown]
# # Data Distributions

# %% [markdown]
# ## Bool Distributions

# %%
#Note AI was used to create the bar plot framework:
#Prompt: Can you make a bar plot in seaborn to plot field A which is either 1 or 0

# Count plot to show the distribution of 1s and 0s in field A
sns.countplot(x='visit_Grocery Stores', data=data_raw_df)

# Display the plot
plt.title("Distribution of visit_Grocery Stores")
plt.xlabel("visit_Grocery Stores")
plt.ylabel("Count")
plt.show()

# %%
# Count plot to show the distribution of 1s and 0s in field A
sns.countplot(x='visit_Building Material and Supplies Dealers', data=data_raw_df)

# Display the plot
plt.title("Distribution of visit_Building Material and Supplies Dealers")
plt.xlabel("visit_Building Material and Supplies Dealers")
plt.ylabel("Count")
plt.show()

# %%
# Count plot to show the distribution of 1s and 0s in field A
sns.countplot(x='visit_Gasoline Stations', data=data_raw_df)

# Display the plot
plt.title("Distribution of visit_Gasoline Stations	")
plt.xlabel("visit_Gasoline Stations	")
plt.ylabel("Count")
plt.show()
# Out:
# /Users/richardstrom/.pyenv/versions/3.10.4/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Count plot to show the distribution of 1s and 0s in field A
sns.countplot(x='visit_General Merchandise Stores, including Warehouse Clubs and Supercenters', data=data_raw_df)

# Display the plot
plt.title("Distribution of visit_General Merchandise Stores, including Warehouse Clubs and Supercenters")
plt.xlabel("visit_General Merchandise Stores, including Warehouse Clubs and Supercenters")
plt.ylabel("Count")
plt.show()

# %%
# Count plot to show the distribution of 1s and 0s in field A
sns.countplot(x='visit_Health and Personal Care Stores', data=data_raw_df)

# Display the plot
plt.title("Distribution of visit_Health and Personal Care Stores")
plt.xlabel("visit_Health and Personal Care Stores")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Continuous Distributions

# %%
# KDE plot for the continuous field B
sns.histplot(x='FIPS',data = data_raw_df, bins=100, kde=False, color='skyblue', alpha=0.6)

# Add labels and title
plt.title("Hist Plot for FIPS")
plt.xlabel("FIPS")
plt.ylabel("Count")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "fraction_pop_under_5", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for fraction_pop_under_5")
plt.xlabel("fraction_pop_under_5")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "fraction_pop_over_65", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for fraction_pop_over_65")
plt.xlabel("fraction_pop_over_65")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "dis_5to64_rate", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for dis_5to64_rate")
plt.xlabel("dis_5to64_rate")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "lmt_english", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for lmt_english")
plt.xlabel("lmt_english")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "no_vehicle_rate", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for no_vehicle_rate")
plt.xlabel("no_vehicle_rate")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "median_income", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for median_income")
plt.xlabel("median_income")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "white_fraction", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for white_fraction")
plt.xlabel("white_fraction")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "Grocery Stores_density", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for Grocery Stores_density")
plt.xlabel("Grocery Stores_density")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "Building Material and Supplies Dealers_density", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for Building Material and Supplies Dealers_density")
plt.xlabel("Building Material and Supplies Dealers_density")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "General Merchandise Stores, including Warehouse Clubs and Supercenters_density", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for General Merchandise Stores, including Warehouse Clubs and Supercenters_density")
plt.xlabel("General Merchandise Stores, including Warehouse Clubs and Supercenters_density")
plt.ylabel("Density")

# Display the plot
plt.show()

# %%
# KDE plot for the continuous field B
sns.kdeplot(x = "Health and Personal Care Stores_density", data = data_raw_df, fill=True)

# Add labels and title
plt.title("KDE Plot for Health and Personal Care Stores_density")
plt.xlabel("Health and Personal Care Stores_density")
plt.ylabel("Density")

# Display the plot
plt.show()

# %% [markdown]
# ### Notes
#
# Right Skewed Data:
# dis_5to64_rate,
# lmt_english,
# no_vehicle_rate,
# median_income,
# Grocery Stores_density,
# Building Material and Supplies Dealers_density,
# General Merchandise Stores, including Warehouse Clubs and Supercenters_density,
# Health and Personal Care Stores_density,
#
# Left Skewed:
# white_fraction

# %% [markdown]
# ### General Notes
#
# Might be a good idea to do some outlier analysis, some of these skewed dists look skewed due to extreme outliers
